# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv('archive/Fashion Dataset.csv')

# %%
data.head()
# Out:
#    Unnamed: 0        p_id                                               name  \
# 0           0  17048614.0  Khushal K Women Black Ethnic Motifs Printed Ku...
# 1           1  16524740.0  InWeave Women Orange Solid Kurta with Palazzos...
# 2           2  16331376.0  Anubhutee Women Navy Blue Ethnic Motifs Embroi...
# 3           3  14709966.0  Nayo Women Red Floral Printed Kurta With Trous...
# 4           4  11056154.0   AHIKA Women Black & Green Printed Straight Kurta
#
#     price     colour      brand  \
# 0  5099.0      Black  Khushal K
# 1  5899.0     Orange    InWeave
# 2  4899.0  Navy Blue  Anubhutee
# 3  3699.0        Red       Nayo
# 4  1350.0      Black      AHIKA
#
#                                                  img  ratingCount  avg_rating  \
# 0  http://assets.myntassets.com/assets/images/170...       4522.0    4.418399
# 1  http://assets.myntassets.com/assets/images/165...       1081.0    4.119334
# ...

# %%
data['colour'].nunique()
# Out:
# 49

# %%
data['colour'].value_counts()
# Out:
# colour
# Black                1917
# Blue                 1814
# Pink                 1179
# Green                1089
# Navy Blue             846
# White                 811
# Red                   714
# Grey                  572
# Maroon                527
# Yellow                498
# Beige                 487
# Mustard               325
# Off White             314
# Peach                 303
# Purple                296
# Orange                288
# Olive                 257
# Brown                 255
# Teal                  192
# Cream                 157
# Multi                 147
# Burgundy              146
# Sea Green             115
# Turquoise Blue        113
# Rust                  108
# Lavender              102
# Gold                   93
# Magenta                86
# Charcoal               84
# Coral                  81
# Fuchsia                54
# Mauve                  51
# Lime Green             50
# Rose                   44
# Grey Melange           43
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming 'data' is your DataFrame with a column named 'color'

# # Example DataFrame creation
# data = pd.DataFrame({'color': ['red', 'blue', 'green', 'red', 'red', 'blue', 'yellow', 'green', 'green', 'red']})

# Get value counts of the 'color' column
color_counts = data['colour'].value_counts()
plt.figure(figsize=(12, 6))
sns.countplot(data=data, x='colour', palette='viridis')
plt.title('Distribution of Colors')
plt.xlabel('Colors')
plt.ylabel('Frequency')
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.show()
# Out:
# /var/folders/_8/xfc42_6120n2mkkw2ymrm37r0000gn/T/ipykernel_14167/2808574436.py:13: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=data, x='colour', palette='viridis')

# %%
color_counts = data['brand'].value_counts()
plt.figure(figsize=(12, 6))
sns.countplot(data=data, x='brand', palette='viridis')
plt.title('Distribution of Brands')
plt.xlabel('Colors')
plt.ylabel('Frequency')
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.show()
# Out:
# /var/folders/_8/xfc42_6120n2mkkw2ymrm37r0000gn/T/ipykernel_14167/382283171.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=data, x='brand', palette='viridis')

# %%
data['brand'].nunique()
# Out:
# 1022

# %%
value_count_brands = data['brand'].value_counts()
value_count_brands[:20]
# Out:
# brand
# Roadster               346
# Tokyo Talkies          287
# MANGO                  264
# SASSAFRAS              247
# Clora Creation         236
# URBANIC                232
# Mitera                 204
# H&M                    202
# Anouk                  200
# Dupatta Bazaar         171
# DressBerry             157
# Sangria                151
# Vishudh                138
# KALINI                 135
# Readiprint Fashions    124
# Soch                   119
# Vero Moda              113
# Biba                   111
# STREET 9               108
# max                    104
# Name: count, dtype: int64

# %%
# color_counts = data['brand'].value_counts()
plt.figure(figsize=(12, 6))
sns.countplot(data=data, x='brand', palette='viridis')
plt.title('Distribution of Brands')
plt.xlabel('Colors')
plt.ylabel('Frequency')
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.show()

# %%
plt.figure(figsize=(8, 6))
plt.hist(data['price'], bins=250, color='skyblue', edgecolor='black')
plt.xlim(0,10000)
plt.title('Distribution of Price')
plt.xlabel('Price')
plt.ylabel('Frequency')
plt.grid(axis='y', alpha=0.75)
plt.show()

# %%
plt.figure(figsize=(8, 6))
plt.hist(data['avg_rating'], bins=100, color='orange')
plt.title('Distribution of ratings')
plt.xlabel('Price')
plt.ylabel('Frequency')
plt.grid(axis='y', alpha=0.75)
plt.show()

# %%
data['img']
# Out:
# 0        http://assets.myntassets.com/assets/images/170...
# 1        http://assets.myntassets.com/assets/images/165...
# 2        http://assets.myntassets.com/assets/images/163...
# 3        http://assets.myntassets.com/assets/images/147...
# 4        http://assets.myntassets.com/assets/images/110...
#                                ...
# 14325    http://assets.myntassets.com/assets/images/154...
# 14326    http://assets.myntassets.com/assets/images/164...
# 14327    http://assets.myntassets.com/assets/images/163...
# 14328    http://assets.myntassets.com/assets/images/163...
# 14329    http://assets.myntassets.com/assets/images/163...
# Name: img, Length: 14330, dtype: object

# %%
df = data

# %%
# Extract features from the column 'p_attributes'
import ast
for index, row in df.iterrows():

    if  not pd.isna(row['p_attributes']):
      # Get features into the dictionary format
      features_dict = ast.literal_eval(row['p_attributes'])

      # Add features as separate columns to the DataFrame
      for feature, value in features_dict.items():
          df.at[index, feature] = value
# Out:
# /var/folders/_8/xfc42_6120n2mkkw2ymrm37r0000gn/T/ipykernel_14167/2972858013.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.at[index, feature] = value
# /var/folders/_8/xfc42_6120n2mkkw2ymrm37r0000gn/T/ipykernel_14167/2972858013.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.at[index, feature] = value
# ...

# %%
# Dropping unnecessary columns
df = df.drop(columns=['description', 'img', 'p_attributes', 'Add-Ons', 'Body or Garment Size', 'Number of Pockets',
                      'Sustainable', 'Wash Care', 'Weave Pattern', 'Style Tip',
                      'Fabric Purity', 'Shape', 'Care for me', 'Where-to-wear', 'Wedding', 'About the Brand',
                      'Better Cotton Initiative', 'taxMaterial', 'Contact Brand or Retailer for pre-sales product queries',
                      'Collection Name', 'Brand Fit Name', 'Fabric 3', 'Reversible', 'How to care for your denim', 'What it does for your body',
                      'Technology', 'Sport Team', 'Fusion Wear', 'Set Content', 'Regions', 'Technology Present'], axis=1)

# %%
df
# Out:
#        Unnamed: 0        p_id  \
# 0               0  17048614.0
# 1               1  16524740.0
# 2               2  16331376.0
# 3               3  14709966.0
# 4               4  11056154.0
# ...           ...         ...
# 14325         985  15415116.0
# 14326         986  16470114.0
# 14327         987  16382150.0
# 14328         988  16379664.0
# 14329         989  16379656.0
#
#                                                     name   price     colour  \
# 0      Khushal K Women Black Ethnic Motifs Printed Ku...  5099.0      Black
# 1      InWeave Women Orange Solid Kurta with Palazzos...  5899.0     Orange
# 2      Anubhutee Women Navy Blue Ethnic Motifs Embroi...  4899.0  Navy Blue
# 3      Nayo Women Red Floral Printed Kurta With Trous...  3699.0        Red
# 4       AHIKA Women Black & Green Printed Straight Kurta  1350.0      Black
# ...                                                  ...     ...        ...
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'p_id', 'name', 'price', 'colour', 'brand', 'ratingCount',
#        'avg_rating', 'Body Shape ID', 'Bottom Closure', 'Bottom Fabric',
#        'Bottom Pattern', 'Bottom Type', 'Character', 'Dupatta',
#        'Dupatta Border', 'Dupatta Fabric', 'Dupatta Pattern', 'Main Trend',
#        'Neck', 'Occasion', 'Ornamentation', 'Pattern Coverage',
#        'Print or Pattern Type', 'Sleeve Length', 'Sleeve Styling',
#        'Slit Detail', 'Stitch', 'Technique', 'Top Design Styling',
#        'Top Fabric', 'Top Hemline', 'Top Length', 'Top Pattern', 'Top Shape',
#        'Top Type', 'Waistband', 'Weave Type', 'Colour Family',
#        'Design Styling', 'Fabric', 'Fabric 2', 'Hemline', 'Length', 'Pattern',
#        'Center Front Open', 'Closure', 'Fabric Type', 'Lining',
#        'Multipack Set', 'Surface Styling', 'Transparency', 'Type', 'Distress',
#        'Effects', 'Fade', 'Features', 'Fit', 'Shade', 'Stretch',
# ...

# %%
df['Occasion'].value_counts()

# %%
df['Bottom Type'].value_counts()
# Out:
# Bottom Type
# nan            13157
# Trousers         519
# Palazzos         245
# Skirt            195
# Shorts            91
# Sharara           46
# Joggers           23
# Churidar          15
# Salwar            11
# Dhoti Pants        8
# Leggings           7
# Patiala            5
# Pyjamas            5
# Capris             3
# Name: count, dtype: int64

# %%
df['Top Shape'].value_counts()
# Out:
# Top Shape
# nan         13804
# Straight      304
# A-Line        154
# Anarkali       63
# Kaftan          4
# Pathani         1
# Name: count, dtype: int64

# %%
data['description'] = data['description'].to_string()
